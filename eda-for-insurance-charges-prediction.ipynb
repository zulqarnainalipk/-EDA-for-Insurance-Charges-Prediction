# %% [markdown]
# # Problem Statement: Predicting Insurance Charges
#
# Insurance premiums are determined by various factors, impacting the coverage provided by insurance companies. As a data analyst/scientist, you have access to historical data concerning an organization's customers and the corresponding insurance charges incurred.
#
# This dataset comprises user information such as age, sex, BMI, hospitalization history, annual income, etc. Your task is to thoroughly analyze this data, extract valuable insights, and develop a robust linear regression model.
#
# The objective is to create a model capable of accurately predicting insurance charges for a new set of data. By leveraging the provided features, the model will help anticipate insurance costs for prospective customers, aiding in pricing strategies and risk assessment.

# %% [markdown]
# # 📈 Predicting Insurance Charges via Linear Regression
#
# In this analysis, we utilize Linear Regression, a fundamental machine learning technique, to predict insurance charges. Linear Regression is a statistical method used to model the relationship between a dependent variable (in this case, insurance charges) and one or more independent variables (such as age, BMI, smoking habits, etc.).
#
# ### Understanding Linear Regression:
# Linear Regression works by finding the best-fit line that represents the relationship between the independent and dependent variables. This line is determined by minimizing the difference between the observed values and the values predicted by the model.
#
# ### Notebook Workflow Steps:
#
# 1. **Load the Necessary Libraries**
#    - Import libraries required for data manipulation, visualization, and modeling.
#
# 2. **Load the Dataset**
#    - Load the insurance dataset into the notebook for analysis.
#
# 3. **Exploratory Data Analysis (EDA)**
#    - **Shape**: Determine the dimensions of the dataset (rows, columns).
#    - **Null Values**: Identify and handle missing values in the dataset.
#    - **Info**: Get an overview of the dataset including data types.
#    - **Duplicates**: Check for and remove any duplicate entries in the dataset.
#    - **Descriptive Statistics**: Calculate summary statistics for numerical features.
#    - **Outliers**: Detect and deal with outliers in the data if necessary.
#    - *Add any additional exploratory analysis as needed.*
#
# 4. **Feature Engineering**
#    - Perform feature engineering tasks such as encoding categorical variables, feature scaling, etc.
#
# 5. **Feature Selection**
#    - Use techniques like correlation analysis, VIF (Variance Inflation Factor), and Recursive Feature Elimination (RFE) to select the most relevant features for modeling.
#
# 6. **Model Building**
#    - Build various predictive models such as linear regression, logistic regression, decision trees, etc.
#
# 7. **Prediction**
#    - Utilize the trained models to make predictions on the test data or new data.
#
# 8. **Evaluation**
#    - Assess the performance of the models using appropriate evaluation metrics such as mean squared error, accuracy, etc.
#
#
#
#
# ### Benefits of Linear Regression:
# - **Interpretability**: Linear Regression provides insights into how each independent variable contributes to the dependent variable.
# - **Simplicity**: It's a simple yet powerful technique, making it easy to understand and implement.
# - **Fast Computation**: Training and prediction using Linear Regression are computationally efficient, even with large datasets.
#
# ## 👉 [Visit my Kaggle]( https://www.kaggle.com/zulqarnainalipk) 👈
# ## 👉 [Visit my LinkedIn]( https://www.linkedin.com/in/zulqarnainalipk/)👈
#
# ## How to Use 🛠️
# To use this notebook effectively, please follow these steps:
# 1. Ensure you have the  data and environment set up.
# 2. Execute each cell sequentially to perform data preparation, feature engineering, model training, and for prediction .
# 3. Customize and adapt the code as needed to improve model performance or experiment with different approaches.
#
# ### Conclusion:
# By employing Linear Regression, we aim to accurately predict insurance charges based on relevant factors. This predictive model can assist insurance companies in setting premiums, assessing risk, and making informed decisions.

# %% [markdown]
# ## Dataset Description
# ![img.png](data:image/png;base64,...)

# %% [markdown]
# # Importing necessary libraries 📚

# %%
# !pip install autoviz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 24.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 17.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.9/255.9 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 54.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 53.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 6.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.4
#     Uninstalling nltk-3.2.4:
#       Successfully uninstalled nltk-3.2.4
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 2.0.3
#     Uninstalling xgboost-2.0.3:
#       Successfully uninstalled xgboost-2.0.3
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
# ...

# %%
# Importing necessary libraries 📚
import warnings
warnings.filterwarnings('ignore')  # Ignore warnings

import numpy as np  # Numerical operations
import pandas as pd  # Data manipulation
import matplotlib.pyplot as plt  # Data visualization
import seaborn as sns  # Data visualization
import plotly.express as px
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
le=LabelEncoder()
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %% [markdown]
# ### Explanation:
# - **`pd.read_csv()`**: This function is used to read data from a CSV file into a pandas DataFrame.
# - **`'/kaggle/input/insurace-data-with-10000-records/insurance data.csv'`**: This is the file path to the CSV file containing the insurance data. Adjust the path accordingly if the file is located in a different directory.
# - **`insurance`**: This variable stores the DataFrame containing the insurance data after reading it from the CSV file. You can use any valid variable name to store the DataFrame.

# %%
insurance=pd.read_csv('/kaggle/input/insurace-data-with-10000-records/insurance data.csv')

# %% [markdown]
# ###  Explanation:
# - **`insurance.head()`**: This method is used to display the first few rows of the DataFrame.

# %%
insurance.head()
# Out:
#     age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0  45.0    male  28.700       2.0     no   32993.77432                16.0
# 1  64.0    male  34.500       0.0     no   38448.37757                 8.0
# 2  19.0  female  32.110       0.0     no   50778.14448                15.0
# 3  36.0    male  28.880       3.0     no   33741.00388                10.0
# 4  19.0  female  24.605       1.0     no   12198.20493                16.0
#
#    num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 0      902022.0          8.640895e+06                              1.0
# 1      956604.0          1.102239e+07                              1.0
# 2      758688.0          1.642626e+06                              0.0
# 3      879560.0          1.985637e+06                              1.0
# 4      793026.0          1.000938e+07                              1.0
#
#    Anual_Salary     region      charges
# 0  9.436591e+07  southwest   8027.96800
# ...

# %% [markdown]
# ##    EDA

# %% [markdown]
# ### Explanation:
# - **`insurance.shape`**: This attribute of the DataFrame returns a tuple representing the dimensions (number of rows and columns) of the DataFrame.
# - It helps to quickly understand the size of the dataset, providing valuable information about its structure.

# %%
insurance.shape
# Out:
# (10008, 13)

# %% [markdown]
# ###  Explanation:
# - **`insurance.info()`**: This method provides a concise summary of the DataFrame, including information about the data types, non-null values, and memory usage.
# - It helps in understanding the structure of the dataset and identifying any missing or inconsistent data.

# %%
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              9935 non-null   float64
#  1   sex                              10008 non-null  object
#  2   bmi                              9984 non-null   float64
#  3   children                         9963 non-null   float64
#  4   smoker                           10008 non-null  object
#  5   Claim_Amount                     9909 non-null   float64
#  6   past_consultations               9957 non-null   float64
#  7   num_of_steps                     9984 non-null   float64
#  8   Hospital_expenditure             9978 non-null   float64
#  9   NUmber_of_past_hospitalizations  9998 non-null   float64
#  10  Anual_Salary                     9971 non-null   float64
# ...

# %% [markdown]
# ###  Explanation:
# - **`insurance.isna()`**: This method returns a DataFrame of boolean values indicating whether each element in the DataFrame is NaN (null) or not.
# - **`.sum()`**: This method is then applied to calculate the sum of NaN values for each column in the DataFrame.
# - It helps in identifying the count of missing values in each column of the dataset.

# %%
insurance.isna().sum()
# Out:
# age                                73
# sex                                 0
# bmi                                24
# children                           45
# smoker                              0
# Claim_Amount                       99
# past_consultations                 51
# num_of_steps                       24
# Hospital_expenditure               30
# NUmber_of_past_hospitalizations    10
# Anual_Salary                       37
# region                              0
# charges                             0
# dtype: int64

# %% [markdown]
# ###  Explanation:
# - **`insurance["age"].isnull()`**: This part of the code checks for null values in the 'age' column of the DataFrame `insurance`.
# - **`insurance[...]`**: This is boolean indexing, where it selects rows from the DataFrame `insurance` based on the condition provided inside the square brackets.
# - It filters the DataFrame to display only those rows where the 'age' column contains null values, helping to identify specific instances of missing data within the dataset.

# %%
insurance[insurance["age"].isnull()]
# Out:
#       age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 45    NaN  female  42.130       1.0     no   37708.33994                17.0
# 419   NaN    male  25.175       0.0     no   47840.82556                17.0
# 448   NaN    male  25.175       0.0     no   47840.82556                17.0
# 533   NaN    male  28.595       1.0     no   24042.82862                 5.0
# 721   NaN    male  39.500       0.0     no   33218.34635                10.0
# ...   ...     ...     ...       ...    ...           ...                 ...
# 8702  NaN    male  17.860       1.0     no   50569.01375                15.0
# 8787  NaN  female  42.130       1.0     no   37708.33994                17.0
# 8810  NaN  female  28.820       0.0     no   43225.25701                18.0
# 8923  NaN  female  28.820       0.0     no   43225.25701                18.0
# 9308  NaN  female  28.820       0.0     no   43225.25701                18.0
#
# ...

# %% [markdown]
# ###  Explanation:
# - **`insurance.describe()`**: This method generates descriptive statistics for numerical columns in the DataFrame `insurance`, including measures like mean, standard deviation, minimum, maximum, and quartiles.
# - **`.round()`**: This function is applied to round off the descriptive statistics to the nearest integer for better readability.
# - It provides an overview of the central tendency and spread of the numerical features in the dataset.

# %%
insurance.describe().round()
# Out:
#           age     bmi  children  Claim_Amount  past_consultations  \
# count  9935.0  9984.0    9963.0        9909.0              9957.0
# mean     39.0    30.0       1.0       32221.0                14.0
# std      14.0     6.0       1.0       15079.0                 7.0
# min      18.0    16.0       0.0        1920.0                 1.0
# 25%      26.0    26.0       0.0       19541.0                 9.0
# 50%      39.0    30.0       1.0       32800.0                14.0
# 75%      51.0    34.0       2.0       44148.0                19.0
# max      64.0    53.0       5.0       77278.0                40.0
#
#        num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# count        9984.0                9978.0                           9998.0
# mean       896863.0            11198901.0                              1.0
# std         84722.0            19075070.0                              0.0
# ...

# %% [markdown]
# ### Explanation:
# - **`insurance.describe(include='O')`**: This method generates summary statistics for object (categorical) columns in the DataFrame `insurance`.
# - By specifying `include='O'`, it focuses only on object (string) columns in the dataset.
# - It provides information such as the count of unique values, the most frequent value, and the frequency of the most frequent value for each object column.
# - This helps in understanding the distribution and characteristics of categorical features in the dataset.

# %%
insurance.describe(include='O')
# Out:
#            sex smoker     region
# count    10008  10008      10008
# unique       2      2          4
# top     female     no  southeast
# freq      5032   8552       2646

# %% [markdown]
# ### Explanation:
# - **`px.box()`**: This function from the Plotly Express library is used to create a box plot.
# - **`insurance`**: This is the DataFrame containing the insurance data.
# - **`y='age'`**: This parameter specifies that the 'age' column from the DataFrame `insurance` will be used as the y-axis variable in the box plot.
# - **`fig.show()`**: This method displays the generated box plot.
# - The box plot provides visual insights into the distribution of ages in the insurance dataset, showing key statistical measures like median, quartiles, and outliers.

# %%
fig=px.box(insurance,y='age')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# ###  Explanation:
# - **`px.box()`**: This function from the Plotly Express library is used to create a box plot.
# - **`insurance`**: This is the DataFrame containing the insurance data.
# - **`'bmi'`**: This parameter specifies that the 'bmi' column from the DataFrame `insurance` will be used as the variable for the box plot.
# - **`fig.show()`**: This method displays the generated box plot.
# - The box plot provides visual insights into the distribution of BMI (Body Mass Index) values in the insurance dataset, showing key statistical measures like median, quartiles, and outliers.

# %%
fig=px.box(insurance,'bmi')
fig.show()
# Out:
# <div>                            <div id="3732e6f2-cd0b-4916-9bd2-366d380e2bab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3732e6f2-cd0b-4916-9bd2-366d380e2bab")) {                    Plotly.newPlot(                        "3732e6f2-cd0b-4916-9bd2-366d380e2bab",                        [{"alignmentgroup":"True","hovertemplate":"bmi=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[28.7,34.5,32.11,28.88,24.605,34.21,36.0,26.22,28.4,33.0,37.4,27.74,38.83,30.115,41.14,33.99,28.12,35.2,23.21,26.695,44.7,33.82,24.795,28.69,28.69,25.3,38.17,27.455,34.1,34.32,24.32,41.23,39.93,20.235,26.79,32.3,36.29,31.635,24.605,37.51,29.165,
# ...

# %% [markdown]
# ###  Explanation:
# - **`sns.distplot()`**: This function from the Seaborn library is used to plot a histogram along with a kernel density estimate (KDE) of the distribution of the 'bmi' column from the DataFrame `insurance`.
# - **`plt.xlabel('bmi')`**: This function from the Matplotlib library sets the label for the x-axis as 'bmi'.
# - **`plt.show()`**: This method displays the generated distribution plot.
# - The plot provides visual insights into the distribution of BMI (Body Mass Index) values in the insurance dataset, showing the frequency of different BMI values.

# %%
sns.distplot(x=insurance['bmi'])
plt.xlabel('bmi')
plt.show()

# %% [markdown]
# ### Code Explanation:
# - **`sns.distplot()`**: This function from the Seaborn library is used to plot a histogram along with a kernel density estimate (KDE) of the distribution of the 'age' column from the DataFrame `insurance`.
# - **`plt.xlabel('age')`**: This function from the Matplotlib library sets the label for the x-axis as 'age'.
# - **`plt.show()`**: This method displays the generated distribution plot.
# - The plot provides visual insights into the distribution of ages in the insurance dataset, showing the frequency of different age values.

# %%
sns.distplot(x=insurance['age'])
plt.xlabel('age')
plt.show()

# %% [markdown]
# ###  Explanation:
# - **`from autoviz import AutoViz_Class`**: This line imports the `AutoViz_Class` class from the `autoviz` module.
# - **`AV = AutoViz_Class()`**: This line creates an instance of the `AutoViz_Class` class and assigns it to the variable `AV`.
# - **`report = AV.AutoViz('insurance_data.csv')`**: This line generates a comprehensive visualization report using the `AutoViz` functionality from the `autoviz` library. It automatically analyzes the dataset from the CSV file named 'insurance_data.csv' and generates various visualizations to provide insights into the data. The report variable stores the generated visualization report.

# %%
from autoviz import AutoViz_Class
AV=AutoViz_Class()
report=AV.AutoViz('/kaggle/input/insurace-data-with-10000-records/insurance data.csv')
# Out:
# Imported v0.1.904. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)
# Shape of your Data Set loaded: (10008, 13)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  10
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  2
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
# ...

# %% [markdown]
# ###  Explanation:
# - **`insurance.columns`**: This attribute of the DataFrame `insurance` returns a pandas Index object containing the column labels (names) of the DataFrame.
# - It provides a convenient way to access and view the column names present in the insurance dataset.

# %%
insurance.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region', 'charges'],
#       dtype='object')

# %% [markdown]
# ###  Explanation:
# - This loop iterates over a list of column names (`columns_to_fill`) for which missing values need to be filled.
# - For each column, it fills the missing values with the median value of that column using the `fillna()` method.
# - By using a loop, this code provides a more concise and efficient way to handle missing values for multiple columns in the `insurance` DataFrame.

# %%
# Dropping 'sex' and 'region' columns
insurance = insurance.drop(['sex', 'region'], axis=1)

# Filling missing values with median using a loop
columns_to_fill = ['age', 'bmi', 'children', 'Claim_Amount', 'past_consultations', 
                   'num_of_steps', 'Hospital_expenditure', 'NUmber_of_past_hospitalizations', 'Anual_Salary']

for column in columns_to_fill:
    insurance[column] = insurance[column].fillna(insurance[column].median())

# %% [markdown]
# ### Code Explanation:
# - **`insurance.isna()`**: This method returns a DataFrame of boolean values indicating whether each element in the DataFrame is NaN (null) or not.
# - **`.sum()`**: This method is then applied to calculate the sum of NaN values for each column in the DataFrame.
# - It helps in verifying that there are no missing values remaining in any column of the `insurance` dataset after filling them with the median values.

# %%
insurance.isna().sum()
# Out:
# age                                0
# bmi                                0
# children                           0
# smoker                             0
# Claim_Amount                       0
# past_consultations                 0
# num_of_steps                       0
# Hospital_expenditure               0
# NUmber_of_past_hospitalizations    0
# Anual_Salary                       0
# charges                            0
# dtype: int64

# %% [markdown]
# ### Explanation:
# - **`insurance.duplicated()`**: This method checks for duplicate rows in the DataFrame `insurance` and returns a boolean Series indicating whether each row is a duplicate or not.
# - **`.sum()`**: This method is then applied to count the total number of duplicate rows in the DataFrame.
# - It helps in identifying and quantifying the presence of duplicate rows in the dataset.

# %%
insurance.duplicated().sum()
# Out:
# 8674

# %% [markdown]
# ### Understanding the relationship b/w dependant and independant variables

# %% [markdown]
# ###  Explanation:
# - **`plt.figure(figsize=(10,5))`**: This line creates a new figure for the pairplot with a specified figure size of 10 inches in width and 5 inches in height.
# - **`sns.pairplot()`**: This function from the Seaborn library is used to create a pairplot, which is a grid of pairwise plots showing the relationship between different variables.
# - **`insurance`**: This is the DataFrame containing the insurance data.
# - **`y_vars=('charges')`**: This parameter specifies the dependent variable 'charges' to be displayed on the y-axis.
# - **`x_vars=['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount', 'past_consultations', 'num_of_steps', 'Hospital_expenditure', 'Number_of_past_hospitalizations', 'Anual_Salary', 'region']`**: This parameter specifies the independent variables to be displayed on the x-axis in the pairplot.
# - The pairplot provides visual insights into the relationships between different independent variables and the dependent variable 'charges' in the insurance dataset.

# %%
plt.figure(figsize=(10,5))
sns.pairplot(insurance,y_vars=('charges'),x_vars=['age',  'bmi', 'children', 'smoker', 'Claim_Amount',
       'past_consultations', 'num_of_steps', 'Hospital_expenditure',
       'NUmber_of_past_hospitalizations', 'Anual_Salary', ])

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Explanation:
# - **`le.fit_transform(insurance['smoker'])`**: This line uses a label encoder (`le`) to transform the 'smoker' column of the `insurance` DataFrame from categorical (e.g., 'yes' or 'no') to numerical (e.g., 0 or 1) format.
# - **`insurance['smoker'] = ...`**: This line assigns the transformed numerical values back to the 'smoker' column in the `insurance` DataFrame.
# - **`.astype(int)`**: This method converts the data type of the 'smoker' column to integer, ensuring it contains integer values after transformation.
# - Label encoding is often used to convert categorical variables into a format that can be provided to machine learning algorithms for model training.

# %%
insurance['smoker']=le.fit_transform(insurance['smoker'])
insurance['smoker']=insurance['smoker'].astype(int)

# %% [markdown]
# ### Explanation:
# - **`insurance['smoker'].value_counts()`**: This line calculates the frequency of unique values in the 'smoker' column of the `insurance` DataFrame.
# - It returns a Series where the index represents the unique values in the 'smoker' column ('0' for non-smoker, '1' for smoker), and the values represent the count of each unique value.
# - This helps in understanding the distribution of smoking status ('smoker' or 'non-smoker') within the dataset.

# %%
insurance['smoker'].value_counts()
# Out:
# smoker
# 0    8552
# 1    1456
# Name: count, dtype: int64

# %% [markdown]
# **sex or region is not a relative column for our target variable,both are almost equal.so we can drop it from important features**

# %% [markdown]
# ###  Explanation:
# - **`insurance.corr()`**: This method computes the pairwise correlation of columns in the `insurance` DataFrame.
# - It returns a new DataFrame where the rows and columns are the variables (features) in the dataset, and each cell contains the correlation coefficient between the corresponding variables.
# - The resulting `correlation` DataFrame provides insights into the linear relationship between different features in the dataset. Positive values indicate a positive correlation, negative values indicate a negative correlation, and values close to zero indicate little to no correlation.

# %%
correlation=insurance.corr()
correlation
# Out:
#                                     age       bmi    children   smoker   \
# age                              1.000000  0.134701  0.049256 -0.075216
# bmi                              0.134701  1.000000 -0.001203 -0.082202
# children                         0.049256 -0.001203  1.000000  0.001006
# smoker                          -0.075216 -0.082202  0.001006  1.000000
# Claim_Amount                     0.105374  0.043695  0.041574  0.252707
# past_consultations               0.154334  0.082955  0.046728  0.401325
# num_of_steps                     0.562737  0.087073  0.180672  0.587803
# Hospital_expenditure             0.101304  0.189973  0.018686  0.599224
# NUmber_of_past_hospitalizations  0.388006  0.104327  0.212467  0.469645
# Anual_Salary                     0.145723  0.168925  0.038372  0.687255
# charges                          0.321620  0.127468  0.077219  0.734781
#
#                                  Claim_Amount  past_consultations  \
# ...

# %% [markdown]
# ###  Explanation:
# - **`plt.figure(figsize=(10,5))`**: This line creates a new figure for the heatmap with a specified figure size of 10 inches in width and 5 inches in height.
# - **`sns.heatmap()`**: This function from the Seaborn library is used to create a heatmap to visualize the correlation matrix (`correlation` DataFrame).
# - **`annot=True`**: This parameter adds numerical annotations to each cell of the heatmap, displaying the correlation coefficient values.
# - The heatmap provides a visual representation of the correlation matrix, making it easier to identify patterns and relationships between different features in the dataset.

# %%
plt.figure(figsize=(10,5))
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ###  Explanation:
# - **`insurance.columns`**: This attribute of the DataFrame `insurance` returns a pandas Index object containing the column labels (names) of the DataFrame.
# - It provides a convenient way to access and view the column names present in the `insurance` dataset.

# %%
insurance.columns
# Out:
# Index(['age', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'charges'],
#       dtype='object')

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ***Droping the columns age,children,bmi,region,sex due to its insignificant correlation with the target column (charges)***

# %% [markdown]
# ### Explanation:
# - **`x = insurance.drop([...], axis=1)`**: This line creates a new DataFrame `x` by dropping the specified columns (`'charges'`, `'age'`, `'sex'`, `'bmi'`, `'children'`, `'region'`) from the original `insurance` DataFrame along the columns axis (`axis=1`), indicating that columns should be dropped.
# - **`y = insurance['charges']`**: This line assigns the 'charges' column from the original `insurance` DataFrame to the variable `y`, representing the target variable (dependent variable) to be predicted.

# %%
x=insurance.drop(['charges','age','bmi','children',],axis=1)
y=insurance['charges']

# %% [markdown]
# ###  Explanation:
# - **`x.isnull()`**: This method checks for missing values in the DataFrame `x` and returns a DataFrame of boolean values indicating whether each element in `x` is NaN (null) or not.
# - **`.sum()`**: This method is then applied to calculate the sum of NaN values for each column in the DataFrame.
# - It helps in identifying the count of missing values in each column of the features (independent variables) dataset `x`.

# %%
x.isnull().sum()
# Out:
# smoker                             0
# Claim_Amount                       0
# past_consultations                 0
# num_of_steps                       0
# Hospital_expenditure               0
# NUmber_of_past_hospitalizations    0
# Anual_Salary                       0
# dtype: int64

# %% [markdown]
# ### Explanation:
# - **`train_test_split(x, y, test_size=0.25, random_state=0)`**: This function from the `sklearn.model_selection` module is used to split the dataset into training and testing sets.
# - **`x`**: This parameter represents the features (independent variables) dataset.
# - **`y`**: This parameter represents the target variable (dependent variable).
# - **`test_size=0.25`**: This parameter specifies the proportion of the dataset to include in the testing set. Here, 25% of the data will be used for testing.
# - **`random_state=0`**: This parameter sets the random seed for reproducibility, ensuring that the split is the same each time the code is run.
# - The function returns four sets of data: `x_train` (training features), `x_test` (testing features), `y_train` (training target variable), and `y_test` (testing target variable).

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %% [markdown]
# ## Re-Scaling

# %% [markdown]
# ### Explanation:
# - **`sc.fit_transform(x_train)`**: This line fits the StandardScaler (`sc`) to the training data (`x_train`) and then transforms it. It calculates the mean and standard deviation of each feature in the training set and standardizes the features based on these statistics.
# - **`sc.transform(x_test)`**: This line applies the same transformation (standardization) to the testing data (`x_test`) using the parameters learned from the training data.
# - Standardization is a common preprocessing technique used to scale numerical features to have a mean of 0 and a standard deviation of 1, ensuring that all features are on the same scale.

# %%
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %% [markdown]
# ###  Explanation:
# - This line simply prints the transformed training features dataset `x_train`.
# - After applying standardization using `sc.fit_transform()`, `x_train` contains the standardized values of the original features.

# %%
x_train
# Out:
# array([[-0.41460458, -0.53437243, -0.21451817, ..., -0.26402619,
#         -2.07688205, -0.42995069],
#        [-0.41460458, -0.67532218,  0.22168556, ..., -0.32899923,
#          0.05102904, -0.45272897],
#        [-0.41460458, -1.22386078,  0.94869178, ..., -0.31586569,
#          0.05102904, -0.30450883],
#        ...,
#        [ 2.41193671, -0.19635797, -0.6507219 , ...,  0.00769548,
#          0.05102904,  0.42416537],
#        [-0.41460458, -1.36683088, -1.37772812, ..., -0.45549101,
#          0.05102904, -0.39897952],
#        [-0.41460458, -1.34915411, -1.37772812, ..., -0.19925461,
#          0.05102904, -0.3702792 ]])

# %% [markdown]
# ###  Explanation:
# - **`y_train_arr = y_train.values`**: This line converts the pandas Series `y_train` into a NumPy array using the `.values` attribute, which returns a one-dimensional array containing the elements of `y_train`.
# - **`y_train = y_train_arr.reshape((-1, 1))`**: This line reshapes the one-dimensional array `y_train_arr` into a two-dimensional array with a single column and as many rows as needed. This reshaping is necessary to ensure compatibility with the `fit_transform` method of the scaler for inverse transformation.
# - **`y_train_arr`**: This line prints the reshaped array `y_train_arr` after the transformation.

# %%
#after rescaling it will be in two dimension, convert it back to one dimension for the
#inverse transform to work well
y_train_arr = y_train.values
y_train = y_train_arr.reshape((-1,1))

y_train_arr
# Out:
# array([ 1824.2854 ,  7537.1639 ,  7650.77375, ..., 18972.495  ,
#         3877.30425,  3213.62205])

# %% [markdown]
# ###  Explanation:
# - **`model.fit()`**: This method is used to train the machine learning model.
# - **`x_train`**: This parameter represents the training features (independent variables).
# - **`y_train`**: This parameter represents the target variable (dependent variable) corresponding to the training features.
# - Calling `model.fit(x_train, y_train)` fits the model to the training data, allowing it to learn the patterns and relationships between the features and the target variable.

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Code Explanation:
# - **`model.predict()`**: This method is used to make predictions using the trained machine learning model.
# - **`x_test`**: This parameter represents the testing features (independent variables) for which predictions are to be made.
# - The predictions are stored in the variable `prediction`, which contains the predicted values of the target variable (dependent variable) based on the testing features.

# %%
prediction=model.predict(x_test)

# %% [markdown]
# ###  Explanation:
# - **`from sklearn.metrics import r2_score`**: This line imports the R-squared score metric from the `sklearn.metrics` module.
# - **`r2_score(y_test, prediction)`**: This function calculates the R-squared (coefficient of determination) score to evaluate the performance of the machine learning model.
# - **`y_test`**: This parameter represents the actual values of the target variable (dependent variable) in the testing set.
# - **`prediction`**: This parameter represents the predicted values of the target variable (dependent variable) made by the model on the testing set.
# - The R-squared score quantifies the proportion of the variance in the target variable that is predictable from the independent variables. A higher R-squared value indicates a better fit of the model to the data.

# %%
#Evaluation
from sklearn.metrics import *
r2_score(y_test,prediction)
# Out:
# 0.9785581635561494

# %% [markdown]
# The R-squared (R2) score and the Root Mean Squared Error (RMSE) are both commonly used metrics to evaluate the performance of regression models.
#
# - **R-squared (R2) Score**:
#   - The R-squared score quantifies the proportion of the variance in the target variable that is predictable from the independent variables.
#   - It ranges from 0 to 1, where 1 indicates a perfect fit of the model to the data, meaning that all variability in the dependent variable is explained by the independent variables.
#   - A higher R-squared value indicates a better fit of the model to the data.
#
# - **Root Mean Squared Error (RMSE)**:
#   - The RMSE measures the average magnitude of the errors between predicted values and actual values.
#   - It represents the square root of the average of the squared differences between predicted and actual values.
#   - Lower values of RMSE indicate better performance, as they suggest that the model's predictions are closer to the actual values.
#
# When comparing the R-squared score and RMSE:
# - A high R-squared score close to 1 indicates that a large proportion of the variability in the target variable is explained by the independent variables, suggesting a good model fit.
# - A low RMSE indicates that the model's predictions are close to the actual values, which also suggests a good model fit.
#
# In summary, a good model typically exhibits both a high R-squared score and a low RMSE.

# %% [markdown]
# ###  Explanation:
# - **`mean_absolute_error(y_test, prediction)`**: This function calculates the mean absolute error (MAE) between the actual values (`y_test`) and the predicted values (`prediction`). MAE represents the average of the absolute differences between the predicted and actual values.
# - **`mean_squared_error(y_test, prediction)`**: This function calculates the mean squared error (MSE) between the actual values (`y_test`) and the predicted values (`prediction`). MSE represents the average of the squared differences between the predicted and actual values.
# - **`np.sqrt(mean_squared_error(y_test, prediction))`**: This line calculates the square root of the MSE to obtain the root mean squared error (RMSE). RMSE represents the square root of the average of the squared differences between the predicted and actual values.
# - These metrics are commonly used to evaluate the performance of regression models. Lower values indicate better performance for MAE, MSE, and RMSE.

# %%
print('Mean Absolute Error: ',mean_absolute_error(y_test,prediction))
print('Mean squared Error: ',mean_squared_error(y_test,prediction))
print('Root Mean Square Error: ',np.sqrt(mean_squared_error(y_test,prediction)))
# Out:
# Mean Absolute Error:  893.7624528866178
# Mean squared Error:  1920857.2652064834
# Root Mean Square Error:  1385.9499504695266

# %% [markdown]
# ## Keep Exploring! 👀
#
# Thank you for delving into this notebook! If you found it insightful or beneficial, I encourage you to explore more of my projects and contributions on my profile.
#
# 👉 [Visit my Profile](https://www.kaggle.com/zulqarnainalipk) 👈
#
# [GitHub]( https://github.com/zulqarnainalipk) |
# [LinkedIn]( https://www.linkedin.com/in/zulqarnainalipk/)
#
# ## Share Your Thoughts! 🙏
#
# Your feedback is invaluable! Your insights and suggestions drive our ongoing improvement. If you have any comments, questions, or ideas to contribute, please feel free to reach out.
#
# 📬 Contact me via email: [zulqar445ali@gmail.com](mailto:zulqar445ali@gmail.com)
#
# I extend my sincere gratitude for your time and engagement. Your support inspires me to create even more valuable content.
# Happy coding and best of luck in your data science endeavors! 🚀
